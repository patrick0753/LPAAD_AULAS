# %% [markdown]
#  1. Desenvolva um programa que solicite ao usuário a temperatura atual. Caso a temperatura seja superior a 30°, exiba uma mensagem recomendando que ele se hidrate

# %%
temperatura = float(input("insira a temperatura"))
if temperatura >30:
    print("se hidrate")

# %% [markdown]
# 2. Desenvolva um programa que solicite ao usuário um número inteiro e determine se o número informado é PAR ou ÍMPAR

# %%
n1 = int(input("entre com n1: "))
if n1%2 == 0:
    print(f'{n1} é par')
else:
    print(f'{n1} é ímpar')
# Out:
# 5 é ímpar

# %% [markdown]
# 3.

# %%
saldo = float(input("digite seu saldo: "))
val_transacao = float(input("digite o valor da transação: "))
if saldo >= val_transacao:
    saldo_suficiente = True
else:
    saldo_suficiente = False
if saldo_suficiente is True:
    print("transação aprovada")
else:
    print("transação negada")
# Out:
# transação aprovada

# %%
idade = 20
renda = 2000
vip = False
negativado = False
if (idade >=20 and renda >=1500)

# %%
lista = [120,150,74,33,4]
n1 = int(input("insira um valor: "))
n2= int(input("insira um valor: "))
n3= int(input("insira um valor: "))
n4= int(input("insira um valor: "))
lista.append(n1,n2,n3,n4)
print(lista)
qtd= len(lista)
print(lista)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       2 n1 = int(input("insira um valor: "))
#       3 n2= int(input("insira um valor: "))
#       4 n3= int(input("insira um valor: "))
#       5 n4= int(input("insira um valor: "))
# ----> 6 lista.append(n1,n2,n3,n4)
#       7 print(lista)
#       8 qtd= len(lista)
#       9 print(lista)
#
# TypeError: list.append() takes exactly one argument (4 given)

# %%
producao =[120,135,128,142,150]

# %%
dia = ['segunda','terça','quarta','quinta','sexta']
faturamento = [18500,21300,17800,24600,27400]
dias_analisados = len(dia)
print(f'dias_analisados: {dias_analisados}')
fat_total= sum(faturamento)
print(f'fat_total: {fat_total}')
fat_med_diario= fat_total/dias_analisados
print(f'fat_med_diario: {fat_med_diario}')
maior_fat_registrado = max(faturamento)
print(f'maior_fat_registrado: {maior_fat_registrado}')
menor_fat_registrado = min(faturamento)
print(f'menor_fat_registrado: {menor_fat_registrado}')

if fat_med_diario >=22.000:
    print('Bom desempenho')
elif fat_med_diario >=19.000 and fat_med_diario<21.999:
    print('desempenho regular')
else:
    print('desempenho crítico')
# Out:
# dias_analisados: 5
# fat_total: 109600
# fat_med_diario: 21920.0
# maior_fat_registrado: 27400
# menor_fat_registrado: 17800
# Bom desempenho

# %% [markdown]
# ## Problema 2 - Controle de velocidade
# *Situação*: Um radar registrou a velocidade de um veículo em uma via cujo limite é de 70 **70km/h**

# %%
print(f'{'*'*5}||CONTROLE DE TRÁFEGO E PREVENÇÃO DE ACIDENTES||{'*'*5}')
limite_vel =70
velocidade =  float(input('Digite a velocidade em km/h'))
excedente = velocidade-limite_vel
val_multa = excedente*9
percentual = (velocidade - limite_vel)/limite_vel*100
if velocidade>limite_vel:
    print('Multado!')
print(f'O valor da multa é de: {val_multa}')
print(f'o percentual de excesso de velocidade é de: {percentual:.2f}')
# Out:
# *****||CONTROLE DE TRÁFEGO E PREVENÇÃO DE ACIDENTES||*****
# Multado!
# O valor da multa é de: 90.0
# o percentual de excesso de velocidade é de: 14.29

# %% [markdown]
# ### Problema 3 - **Monitoramento de Produção Industrial**

# %%
producoes= [485,510,472,498,455,520]


producao_media= sum(producoes)/len(producoes)
qtd_turnos= len(producoes)
soma_und=sum(producoes)
maior= max(producoes)
menor= min(producoes)


if producao_media >=500:
    print('Meta atingida')
elif producao_media >480:
    print('Atenção')
else:
    print('Abaixo da meta')

if min_producoes == menor:
    print('ALERTA! Baixa produção diária')

print(f'A produção média é de: {producao_media}')
print(f'A quantidade de turnos é de: {qtd_turnos}')
print(f'A soma das unidades dos {qtd_turnos} turnos é de {soma_und}')
print(f'O maior número de unidades foi de: {maior}, e o menor: {menor}')
# Out:
# Atenção
# ALERTA! Baixa produção diária
# A produção média é de: 490.0
# A quantidade de turnos é de: 6
# A soma das unidades dos 6 turnos é de 2940
# O maior número de unidades foi de: 520, e o menor: 455

# %% [markdown]
# ### Problema 4 - **Análise de rentabilidade de uma empresa**
# Uma empresa deseja avaliar o desempenho financeiro de suas operações. O setor financeiro disponibilizou os dados dos últimos cinco meses:

# %%
meses = ['janeiro','fevereiro','março','abril','maio']
